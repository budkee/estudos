# %% [markdown]
# # Inteligencia Artificial

# %% [markdown]
# ## Anotações da Aula | 07/02/25

# %%
# Definição de classes
class Narciso():
    def __init__(self, atributo_pub, atributo_priv, atributo_prot):
        
        # Atributo público
        self.atributo_pub = atributo_pub
        # Atributo privado
        self.__atributo_priv = atributo_priv
        # Atributo protegido
        self._atributo_prot = atributo_prot

    def getAtributoPriv(self):
        return self.__atributo_priv

    def setAtributoPriv(self):
        self.__atributo_priv = atributo_priv

eu = Narciso(
    atributo_pub="Kaê", 
    atributo_priv="Kaeu", 
    atributo_prot="sirius"
)

print(eu.getAtributoPriv())

# %%
# Generalización - Especialización
class Produto():
    def __init__(self, precio=0):
        self.precio = precio

class Microprocesador(Produto):
    def __init__(self, precio=0, nucleo=1):
        super().__init__(precio)
        self.__nucleo = nucleo

# %%
# Estruturas controle
vector = ["Kaê", 24, "NB"]
# for x in vector:
#     print(x)
vector2 = [print(x) for x in vector]
# Out:
# Kaê
# 24
# NB

# %%
# Almacenamiento y recuperación de datos
# fichero = open("datos.txt", mode="r")
# nombres = [print(nombre) for nombre in fichero.readlines]
# fichero.close()

with open("datos.txt", mode="r") as fichero:
    # Una linea
    # print(fichero.readline())
    # Todas as lineas
    # print(fichero.readlines())
    lineas = fichero.readlines()
    for registro in lineas:
        print(registro)
# Out:
# Ursula Aznarte, 11112222, ursula@aznarte.es
#
# Javier Lopez, 22223333, javier@lopez.es
#
# Esteban Aguilera, 33334444, esteban@aguilera.es
#
# Maria Diaz, 44445555, maria@diaz.es
#
# Manuel Crespo, 55556666, manuel@crespo.com
#
# Lucia Moral, 66667777, lucia@moral.com

# %% [markdown]
# ## Actividad de Entrega
#
# Diseñar un programa en Python para resolver los siguientes puntos:

# %% [markdown]
# #### 1. Definir una clase Alumno, que contenga las siguientes características:
#
# - [x] Nombre
# - [x] Primer apellido
# - [x] DNI
# - [x] Correo electrónico
# - [x] `getAtributos()`: Consultar los valores de las características anteriormente nombradas
# - [x] `__init__()`: Escribir el constructor para que inicialice todos sus campos a unos valores que se le pasen como parámetros

# %%
## 1.
class Alumno():
    
    # Construtor
    def __init__(self, nombre='', p_apellido='', dni='', correo=''):
        self.nombre = nombre
        self.p_apellido = p_apellido
        self.dni = dni
        self.correo = correo

    # Pillar un atributo específico
    def get_atributo(self, atributo):
        return getattr(self, atributo, None)  

## Test 1
# Instancia del constructor pasando valores como parámetros
eu = Alumno(
    nombre="Kaê", 
    p_apellido="de Oliveira", 
    dni="GJ854298", 
    correo="kob00001@red.ujaen.es"
)

# print(eu.getAtributos(atributo="p_apellido"))

# %% [markdown]
# #### 2. Definir un método que lea una serie de valores que se introduzcan por teclado y cree un nuevo objeto de la clase Alumno, inicializado con dichos valores. Definir otro método que muestre los datos de ese alumno por pantalla.
#
# - [x] `nuevo_alumno()`: ler valores por teclado y crea un novo objeto de Alumno con estos valores
# - [x] `get_alumno()`: mostrar valores do alumno

# %%
class Alumno():
    
    def __init__(self, nombre='', p_apellido='', dni='', correo=''):
        self.nombre = nombre
        self.p_apellido = p_apellido
        self.dni = dni
        self.correo = correo

    # Pillar un atributo específico
    def get_atributo(self, atributo):
        return getattr(self, atributo, None)  

    ## 2 
    @classmethod
    def nuevo_alumno(obj):
        print('## Nuevo Alumno')
        nombre = input('>> Insira o nome del alumno: ')
        p_apellido = input('>> Insira o primeiro apellido del alumno: ')
        dni = input('>> Insira o DNI del alumno: ')
        correo = input('>> Insira o email del alumno: ')
        return obj(nombre, p_apellido, dni, correo)
    
    def get_alumno(self):
        # alumno = [print(f'>> {atributo}: {valor}\n') for atributo, valor in self.__dict__.items()]
        print('\n## Datos del Alumno')
        for atributo, valor in self.__dict__.items():
            print(f'>> {atributo}: {valor}')

## Test 2
# Crear nuevo alumno
# aluno = Alumno.nuevo_alumno()

# Leer los datos del alumno
# aluno.get_alumno()

# %% [markdown]
# #### 3. Definir una clase Alumno_IA, subclase de la anterior, que contenga los siguientes campos adicionales:
#
# - [x] Grupo de teoría
# - [x] Grupo de prácticas
# - [x] Nota asociada a las prácticas 1, 2, 3 y 4
# - [x] `__init__()`: Defina un contructor similar a la de la clase Alumno
# - [x] `get_alumno_ia()`: métodos para poder consultar estos nuevos campos.

# %%
# 3.
class Alumno_IA(Alumno):
    
    # Constructor
    def __init__(
        self, nombre='', 
        p_apellido='', 
        dni='', 
        correo='',
        grupo_teoria='', 
        grupo_pratica='', 
        nota_pratica_1=0, 
        nota_pratica_2=0, 
        nota_pratica_3=0, 
        nota_pratica_4=0
    ):
        super().__init__(nombre, p_apellido, dni, correo)
        
        self.grupo_teoria = grupo_teoria
        self.grupo_pratica = grupo_pratica
        self.nota_pratica_1 = nota_pratica_1
        self.nota_pratica_2 = nota_pratica_2
        self.nota_pratica_3 = nota_pratica_3
        self.nota_pratica_4 = nota_pratica_4

    # Pillar atributos especificos
    def get_atributo(self, atributo):
        return getattr(self, atributo, None)  

    # Anãdir más detalles del alumno 
    def anadir_detalles(self):
        print('## Más detalles del alumno de IA')
        self.grupo_teoria = input('>> Insira el grupo teórico del alumno: ')
        self.grupo_pratica = input('>> Insira el grupo práctico del alumno: ')
        # self.nota_pratica_1 = input('>> Insira la nota práctica 1 del alumno: ')
        # self.nota_pratica_2 = input('>> Insira la nota práctica 2 del alumno: ')
        # self.nota_pratica_3 = input('>> Insira la nota práctica 3 del alumno: ')
        # self.nota_pratica_4 = input('>> Insira la nota práctica 4 del alumno: ')
    
    def get_alumno_ia(self):
        print('\n## Datos del Alumno de IA')
        for atributo, valor in self.__dict__.items():
            print(f'>> {atributo}: {valor}')

## Test 3
# Crear nuevo alumno de IA
aluno = Alumno_IA.nuevo_alumno()

# Añadir detalles del alumno de IA
aluno.anadir_detalles()

# Leer los datos del alumno
aluno.get_alumno_ia()
# Out:
# ## Nuevo Alumno
# >> Insira o nome del alumno:  Kaê
# >> Insira o primeiro apellido del alumno:  de Oliveira
# >> Insira o DNI del alumno:  3133123
# >> Insira o email del alumno:  kasjdksd
# ## Más detalles del alumno de IA
# >> Insira el grupo teórico del alumno:  B1
# >> Insira el grupo práctico del alumno:  B2
# ## Datos del Alumno de IA
# >> nombre: Kaê
# >> p_apellido: de Oliveira
# >> dni: 3133123
# >> correo: kasjdksd
# >> grupo_teoria: B1
# >> grupo_pratica: B2
# >> nota_pratica_1: 0
# >> nota_pratica_2: 0
# >> nota_pratica_3: 0
# >> nota_pratica_4: 0

# %% [markdown]
# #### 4. Definir un método que lea desde teclado las 4 notas de prácticas de un alumno de IA, actualice los campos de notas del alumno, y calcule su nota de prácticas como la media de esos 4 valores. Mostrar el resultado por pantalla.

# %%
class Alumno_IA(Alumno):
    
    def __init__(
        self, nombre='', 
        p_apellido='', 
        dni='', 
        correo='',
        grupo_teoria='', 
        grupo_pratica='', 
        nota_pratica_1=0, 
        nota_pratica_2=0, 
        nota_pratica_3=0, 
        nota_pratica_4=0
    ):
        super().__init__(nombre, p_apellido, dni, correo)
        
        self.grupo_teoria = grupo_teoria
        self.grupo_pratica = grupo_pratica
        self.nota_pratica_1 = nota_pratica_1
        self.nota_pratica_2 = nota_pratica_2
        self.nota_pratica_3 = nota_pratica_3
        self.nota_pratica_4 = nota_pratica_4

    def get_atributo(self, atributo):
        return getattr(self, atributo, None)  

    def anadir_detalles(self):
        print('\n## Más detalles del alumno de IA')
        self.grupo_teoria = input('>> Insira el grupo teórico del alumno: ')
        self.grupo_pratica = input('>> Insira el grupo práctico del alumno: ')

    # 4. Leer, actualizar y calcular la media de las notas
    def calcular_nota_practica(self):
        print('\n## Notas prácticas de IA del alumno')
        self.nota_pratica_1 = float(input('>> Insira la nota práctica 1 del alumno: '))
        self.nota_pratica_2 = float(input('>> Insira la nota práctica 2 del alumno: '))
        self.nota_pratica_3 = float(input('>> Insira la nota práctica 3 del alumno: '))
        self.nota_pratica_4 = float(input('>> Insira la nota práctica 4 del alumno: '))
        
        print('\n## Media de las notas del alumno')
        media = (self.nota_pratica_1 + self.nota_pratica_2 + self.nota_pratica_3 + self.nota_pratica_4)/4

        return media
        
    def get_alumno_ia(self):
        print('\n## Datos del Alumno de IA')
        for atributo, valor in self.__dict__.items():
            print(f'>> {atributo}: {valor}')

## Test 4
# Crear nuevo alumno de IA
aluno = Alumno_IA.nuevo_alumno()

# Añadir detalles del alumno de IA
aluno.anadir_detalles()

# Leer los datos del alumno
aluno.get_alumno_ia()

# Calcular la media
aluno.calcular_nota_practica()
# Out:
# ## Nuevo Alumno
# >> Insira o nome del alumno:  Kaê
# >> Insira o primeiro apellido del alumno:  de Oliveira
# >> Insira o DNI del alumno:  7777777
# >> Insira o email del alumno:  kae.budke@gmail.com
# ## Más detalles del alumno de IA
# >> Insira el grupo teórico del alumno:  2B
# >> Insira el grupo práctico del alumno:  5E
# ## Datos del Alumno de IA
# >> nombre: Kaê
# >> p_apellido: de Oliveira
# >> dni: 7777777
# >> correo: kae.budke@gmail.com
# >> grupo_teoria: 2B
# >> grupo_pratica: 5E
# >> nota_pratica_1: 0
# >> nota_pratica_2: 0
# >> nota_pratica_3: 0
# >> nota_pratica_4: 0
#
# ## Notas prácticas de IA del alumno
# >> Insira la nota práctica 1 del alumno:  10
# >> Insira la nota práctica 2 del alumno:  10
# >> Insira la nota práctica 3 del alumno:  10
# >> Insira la nota práctica 4 del alumno:  10
# ## Media de las notas del alumno
# 10.0

# %% [markdown]
# #### 5. Se dispone de un archivo “datos.txt” (en PLATEA) con datos sobre alumnos (un alumno por línea).
#
# - [ ] Definir los métodos necesarios para leer el contenido de dicho archivo
# - [ ] volcar en un nuevo archivo “impares.txt” una lista con los alumnos cuyo número de DNI sea impar.

# %%
with open('datos.txt', mode='r') as datos:
    # Poner las lineas en una lista 
    lineas = [[valor.strip() for valor in linea.strip().split(',')] for linea in datos.readlines()]
    # print(lineas[0])

    ## Pillar solo los DNIs ímpares y grabar en un archivo externo
    # print(lineas[0][1])
    with open('impares.txt', mode='w') as salida:
        for linea in lineas:
            dni = linea[1]
            if dni[-1].isdigit() and int(dni) % 2 != 0:
                print(dni, file=salida)

# %%
help(str)

# %% [markdown]
# ### Formato de entrega
#
# Se creará un documento (en formato pdf) que incluirá una descripción breve, en lenguaje natural, sobre cómo se ha resuelto cada uno de los ejercicios planteados, sin incluir código fuente. Extensión máxima recomendada: 3 páginas.
# Solo se admitirá el formato PDF. No se corregirán guiones en cualquier otro formato diferente al indicado.
# El documento incluirá una portada con:
#
# - o Identificación de los dos alumnos (Nombre, apellidos y DNI).
# - o Identificación del guión.
#
# El documento incluirá un índice con las secciones y subsecciones del documento.
# - El nombre del fichero tendrá el siguiente formato “Ape11-Ape12-Ape21-
# Ape22-GuionX.pdf” donde
# o Ape11 es el primer apellido del primer alumno.
# o Ape12 es el segundo apellido del primer alumno.
# o Ape21 es el primer apellido del segundo alumno.
# o Ape22 es el segundo apellido del segundo alumno.
# o X es el número del guión de prácticas.
# - Se generará un fichero comprimido (en formato zip) que incluya el
# documento y el código asociado a ambas actividades
